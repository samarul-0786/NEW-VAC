# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mob=dataset=pd.read_csv('C:/Users/ADMIN/Downloads/mobiles.csv')

# %%
mob
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
mob.shape
# Out:
# (2000, 21)

# %%
mob.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
mob.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
mobile=mob.drop(['blue','clock_speed','dual_sim','fc','four_g','m_dep','mobile_wt','pc','px_height','px_width','sc_h','sc_w','talk_time','three_g','touch_screen'],axis=1)

# %%
mobile
# Out:
#       battery_power  int_memory  n_cores   ram  wifi  price_range
# 0               842           7        2  2549     1            1
# 1              1021          53        3  2631     0            2
# 2               563          41        5  2603     0            2
# 3               615          10        6  2769     0            2
# 4              1821          44        2  1411     0            1
# ...             ...         ...      ...   ...   ...          ...
# 1995            794           2        6   668     0            0
# 1996           1965          39        4  2032     1            2
# 1997           1911          36        8  3057     0            3
# 1998           1512          46        5   869     1            0
# 1999            510          45        6  3919     1            3
#
# [2000 rows x 6 columns]

# %%
x=mobile.iloc[:,0].values.reshape(-1,1)
y=mobile.iloc[:,-1].values.reshape(-1,1)

# %%
x
# Out:
# array([[ 842],
#        [1021],
#        [ 563],
#        ...,
#        [1911],
#        [1512],
#        [ 510]], dtype=int64)

# %%
y
# Out:
# array([[1],
#        [2],
#        [2],
#        ...,
#        [3],
#        [0],
#        [3]], dtype=int64)

# %%
plt.plot(x,color='black')
plt.plot(y,color='green')
plt.show()

# %%
plt.plot(x,color='red')
plt.plot(y,color='green')
plt.xlabel('n_cores',)
plt.ylabel('wifi')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,
                                              train_size=0.7,
                                              random_state=0)

# %%
x_train.shape
# Out:
# (1400, 1)

# %%
x_test
# Out:
# array([[1454],
#        [1092],
#        [1524],
#        [1807],
#        [1086],
#        [ 909],
#        [ 642],
#        [ 888],
#        [ 914],
#        [1131],
#        [1020],
#        [ 790],
#        [1617],
#        [1562],
#        [ 808],
#        [1799],
#        [1406],
#        [1788],
#        [1330],
#        [1093],
#        [1027],
#        [1971],
#        [1567],
#        [ 586],
#        [1709],
#        [1339],
#        [1589],
#        [ 727],
#        [1062],
#        [1854],
#        [1449],
#        [1510],
#        [1749],
#        [1339],
#        [ 643],
#        [1755],
#        [1081],
#        [ 637],
#        [1889],
#        [1456],
#        [ 956],
#        [ 769],
#        [1240],
#        [ 595],
#        [1057],
#        [1928],
#        [ 899],
#        [ 615],
#        [ 648],
#        [1344],
#        [1772],
#        [ 948],
#        [1114],
#        [1853],
#        [ 823],
#        [1231],
#        [1122],
#        [ 930],
# ...

# %%
x_test.shape
# Out:
# (600, 1)

# %%
y_train.shape
# Out:
# (1400, 1)

# %%
y_test.shape
# Out:
# (600, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
ln=LinearRegression()

# %%
ln.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=ln.predict(x_test)

# %%
y_predict
# Out:
# array([[1.5941988 ],
#        [1.41135853],
#        [1.62955466],
#        [1.77249332],
#        [1.40832802],
#        [1.31892822],
#        [1.18407089],
#        [1.30832146],
#        [1.32145364],
#        [1.43105679],
#        [1.3749925 ],
#        [1.25882327],
#        [1.67652743],
#        [1.64874783],
#        [1.26791477],
#        [1.76845265],
#        [1.56995479],
#        [1.76289673],
#        [1.53156843],
#        [1.41186361],
#        [1.37852809],
#        [1.85532704],
#        [1.65127325],
#        [1.15578621],
#        [1.72299513],
#        [1.53611418],
#        [1.66238509],
#        [1.227003  ],
#        [1.39620602],
#        [1.79623225],
#        [1.59167338],
#        [1.62248348],
#        [1.74319847],
#        [1.53611418],
#        [1.18457597],
#        [1.74622897],
#        [1.40580261],
#        [1.18154547],
#        [1.81391018],
#        [1.59520897],
#        [1.34266715],
#        [1.24821651],
#        [1.4861109 ],
# ...
